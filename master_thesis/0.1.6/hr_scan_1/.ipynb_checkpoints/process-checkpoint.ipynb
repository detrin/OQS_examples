# %%
using Revise
using OpenQuantumSystems
using LinearAlgebra
using SparseArrays
using Interpolations
using HDF5
using Measures

import Base.log10

# %%
using BenchmarkTools
using Plots
using ProgressBars
using OpenQuantumSystems
# using OpenQuantumSystemsPrivate
using LinearAlgebra
using Random
using QuadGK
using ProgressMeter
using Expokit
# using DifferentialEquations

Random.seed!(0)

import OrdinaryDiffEq, DiffEqCallbacks, DelayDiffEq
import SparseArrays: sparse
import QuantumOpticsBase

# %%
sim_labels = [
    "Evolution_sI_exact",
    "QME_sI_ansatz_test",
    "QME_sI_ansatz_const_int",
    "QME_sI_ansatz_const_sch",
    "QME_sI_ansatz_upart1_sch",
    "QME_sI_ansatz_upart1_int",
    "QME_sI_ansatz_upart2_sch",
    "QME_sI_ansatz_upart2_int",
    "QME_sI_iterative_1"
]
# Out:
# 9-element Vector{String}:
#  "Evolution_sI_exact"
#  "QME_sI_ansatz_test"
#  "QME_sI_ansatz_const_int"
#  "QME_sI_ansatz_const_sch"
#  "QME_sI_ansatz_upart1_sch"
#  "QME_sI_ansatz_upart1_int"
#  "QME_sI_ansatz_upart2_sch"
#  "QME_sI_ansatz_upart2_int"
#  "QME_sI_iterative_1"

# %%
function read_data_pt(filename)
    simulation_info, rho_int_l = h5open(filename, "r") do file
        simulation_info = Dict{String,Any}("n" => read(file, "n"))
        for key in ["hr1", "hr2", "tspan", "tspan_fs"]
            simulation_info[key] = read(file, key)
        end
        rho_int_l = []
        for li=1:length(sim_labels)
            label = sim_labels[li]
            push!(rho_int_l, read(file, label))
        end
        return simulation_info, rho_int_l
    end
    return simulation_info, rho_int_l
end
# Out:
# read_data_pt (generic function with 1 method)

# %%
function get_agg(hr1, hr2)
    mols = [
        Molecule([Mode(omega=200., hr_factor=hr1)], 3, [0., 12700.]),
        Molecule([Mode(omega=200., hr_factor=hr2)], 3, [0., 12500.])
    ]

    aggCore = AggregateCore(mols)
    for mol_i in 2:aggCore.molCount
        aggCore.coupling[mol_i, mol_i+1] = 50
        aggCore.coupling[mol_i+1, mol_i] = 50
    end
    agg = setupAggregate(aggCore)
end
# Out:
# get_agg (generic function with 1 method)

# %%
computed_data = []
for filename in readdir("data"; join=true)
    simulation_info, rho_int_l = read_data_pt(filename)
    push!(computed_data, [simulation_info, rho_int_l])
end

simulation_info, rho_int_l = computed_data[1]
tspan = simulation_info["tspan"]
tspan_fs = simulation_info["tspan_fs"]
println("")

# %%
score_int = zeros(Float64, length(sim_labels), 3, 3, 10, 10) # simulations, eli, elj, hr1, hr2
score_sch = zeros(Float64, length(sim_labels), 3, 3, 10, 10)
score_exc = zeros(Float64, length(sim_labels), 3, 3, 10, 10)

computed_n = Dict()
simulation_dic = Dict()
for (sim_info, rho_int_l) in computed_data
    agg = get_agg(sim_info["hr1"], sim_info["hr2"])
    n = sim_info["n"]
    hr1_i = n % 10 + 1
    hr2_i = n ÷ 10 + 1
    computed_n[n] = true
    simulation_dic[n] = [sim_info, rho_int_l]
    rho_l = []
    for i=1:length(rho_int_l)
        push!(rho_l, interaction_pic_to_schroedinger_pic(rho_int_l[i], tspan, agg))
    end

    rho_exc_l = []
    for i=1:length(rho_int_l)
        push!(rho_exc_l, local_st_to_exciton_st(rho_l[i], agg))
    end

    for li = 2:length(sim_labels)
        label = sim_labels[li]
        score_int[li-1, :, :, hr2_i, hr1_i] = compare_rho(rho_int_l[1], rho_int_l[li])
        score_sch[li-1, :, :, hr2_i, hr1_i] = compare_rho(rho_l[1], rho_l[li])
        score_exc[li-1, :, :, hr2_i, hr1_i] = compare_rho(rho_exc_l[1], rho_exc_l[li])
    end
end

for n=0:99
    if !haskey(computed_n, n)
        println(n)
    end
end

# %%
p_l = []
for li=1:8
    heatmap(log10.(score_int[li, 2, 2, :, :]), clim=(-5, 3))
    p = plot!(
        ylabel="ρ₂₂(t)", xlabel="t (fs)",
        dpi=400, title=sim_labels[li+1]
    )
    push!(p_l, p)
end

plot(
    p_l[1], p_l[2], p_l[3], p_l[4], 
    p_l[5], p_l[6], p_l[7], p_l[8], 
    layout = (4, 2), margin = 5mm, size=(4*200,2*600)
)

# %%
p_l = []
for li in [2, 5, 7, 8]
    heatmap(log10.(score_int[li, 2, 2, :, :]), clim=(-5, 3))
    p = plot!(
        ylabel="ρ₂₂(t)", xlabel="t (fs)",
        dpi=400, title=sim_labels[li+1]
    )
    push!(p_l, p)
end

plot(
    p_l[1], p_l[2], p_l[3], p_l[4],
    layout = (2, 2), margin = 5mm, size=(800,600)
)

# %%
labels = Dict(2 => "const", 5 => "upart1", 7 => "upart2", 8 => "iter1")
p_l = []
for (li, lj) in [2, 5, 7, 8]
    
    label_i = labels[li]
    label_j = labels[lj]
    for lj in [2, 5, 7, 8]
        l
        heatmap(score_int[li, 2, 2, :, :] - score_int[lj, 2, 2, :, :])
        p = plot!(
            ylabel="ρ₂₂(t)", xlabel="t (fs)",
            dpi=400, title="$(label_i) - $(label_j)"
        )
        push!(p_l, p)
    end
end

plot(
    p_l[1], p_l[2], p_l[3], 
    layout = 3, margin = 5mm, size=(800,600)
)

# %%
p_l = []
for li in [2, 5, 7, 8]
    heatmap(log10.(score_sch[li, 2, 2, :, :]), clim=(-5, 3))
    p = plot!(
        ylabel="ρ₂₂(t)", xlabel="t (fs)",
        dpi=400, title=sim_labels[li+1]
    )
    push!(p_l, p)
end

plot(
    p_l[1], p_l[2], p_l[3], p_l[4],
    layout = (2, 2), margin = 5mm, size=(800,600)
)

# %%
p_l = []
for li in [2, 5, 7]
    heatmap(score_sch[li, 2, 2, :, :] - score_sch[8, 2, 2, :, :])
    p = plot!(
        ylabel="ρ₂₂(t)", xlabel="t (fs)",
        dpi=400, title=sim_labels[li+1]
    )
    push!(p_l, p)
end

plot(
    p_l[1], p_l[2], p_l[3], 
    layout = 3, margin = 5mm, size=(800,600)
)

# %%
n, m = 6, 8
li = 2
m = score_sch[li, 2, 2, :, :] - score_sch[8, 2, 2, :, :]
for n=1:10, m=1:10
    println(n, " ", m, " ", score_sch[li, 2, 2, n, m] - score_sch[8, 2, 2, n, m])
end
# Out:
# 1 1 2.531749450252791e-5
# 1 2 0.0001580305690717648
# 1 3 0.0007021718153513008
# 1 4 0.00223538723169892
# 1 5 0.005966880905409393
# 1 6 0.014630435956242006
# 1 7 0.03581027603149439
# 1 8 0.10101839045693602
# 1 9 1.021459589597638
# 1 10 1.6384618684383667
# 2 1 0.00015791277381392398
# 2 2 0.0004350536278838901
# 2 3 0.001237407831256775
# 2 4 0.003226755561540961
# 2 5 0.007784175899291732
# 2 6 0.018106283582434903
# 2 7 0.04345175612016057
# 2 8 0.12600291562523108
# 2 9 3.888182959099109
# 2 10 1.7109629884423128
# 3 1 0.0007002661196444329
# 3 2 0.0012353460999109667
# 3 3 0.0025394129489653963
# 3 4 0.005425472936903238
# 3 5 0.011634383612365717
# 3 6 0.025404239208753475
# 3 7 0.06002726153537427
# 3 8 0.18971142407012476
# 3 9 2.679500665619649
# 3 10 1.3903668786586478
# 4 1 0.0022230161942584166
# 4 2 0.0032141237054701174
# 4 3 0.0054139752948201185
# 4 4 0.009928949265576331
# 4 5 0.019269047173347723
# 4 6 0.04001941740156889
# 4 7 0.09610096559758563
# 4 8 0.41409475001389245
# 4 9 2.6774998277614714
# 4 10 0.9543327210126892
# 5 1 0.005918336409251167
# 5 2 0.007732074916134863
# 5 3 0.011580537969950818
# 5 4 0.019224866209953572
# 5 5 0.03497220383001888
# 5 6 0.07178310809372666
# 5 7 0.19380636426623465
# 5 8 4.11682510158043
# 5 9 1.8899241934359128
# 5 10 -0.6404425106291833
# 6 1 0.014469563291287084
# 6 2 0.01793845130829354
# 6 3 0.02522986767728623
# 6 4 0.03985320456127154
# 6 5 0.07167032981387571
# 6 6 0.1603242856537032
# 6 7 1.4834534452036077
# 6 8 3.548469084338604
# 6 9 1.3019880698145085
# 6 10 -3.0156547043693633
# 7 1 0.03537183632416851
# 7 2 0.04300472229925104
# 7 3 0.05958644851657431
# 7 4 0.09575019786893185
# 7 5 0.1941803654568261
# 7 6 1.9668588802692062
# 7 7 2.482145311812981
# 7 8 1.5111939862655275
# 7 9 -0.13296968998936753
# 7 10 -1453.7343144526037
# 8 1 0.10019487466982094
# 8 2 0.12542394209472285
# 8 3 0.19036810175313998
# 8 4 0.43053304842648243
# 8 5 3.3668712249317236
# 8 6 4.405812753962794
# 8 7 1.5085425864438269
# 8 8 1.0016744307218475
# 8 9 -22.40933648833421
# 8 10 -0.6414563278125915
# 9 1 3.8661409254148276
# 9 2 3.437888760500191
# 9 3 3.324104602330544
# 9 4 1.9972616270356622
# 9 5 1.6833523224191933
# 9 6 7.88899095338532
# 9 7 0.16355004726882094
# 9 8 -3.0542917508745817
# 9 9 -0.43064878905375403
# 9 10 -0.6838502434174065
# 10 1 1.6616319918002935
# 10 2 1.618416115436204
# 10 3 1.6277485164535461
# 10 4 1.0512404649327203
# 10 5 1.1542743322512727
# 10 6 -2.7242444292822094
# 10 7 -1.3775329087885555
# 10 8 -1.316327875664117
# 10 9 -2.222849234147084
# 10 10 -0.5450983889347083

# %%
compare_rho(rho_l[1], rho_l[li])
# Out:
# 3×3 Matrix{Float64}:
#  0.0  0.0         0.0
#  0.0  9.19594e-5  0.0011732
#  0.0  0.0011732   6.64372e-5

# %%
sim_info, rho_int_l = simulation_dic[97]
agg = get_agg(sim_info["hr1"], sim_info["hr2"])

for i=1:length(rho_int_l)
    rho_int_l[i] = operator_recast(rho_int_l[i])
end

rho_l = []
for i=1:length(rho_int_l)
    push!(rho_l, interaction_pic_to_schroedinger_pic(rho_int_l[i], tspan, agg))
end

rho_exc_l = []
for i=1:length(rho_int_l)
    push!(rho_exc_l, local_st_to_exciton_st(rho_l[i], agg))
end
println("")

# %%
sim_labels
# Out:
# 9-element Vector{String}:
#  "Evolution_sI_exact"
#  "QME_sI_ansatz_test"
#  "QME_sI_ansatz_const_int"
#  "QME_sI_ansatz_const_sch"
#  "QME_sI_ansatz_upart1_sch"
#  "QME_sI_ansatz_upart1_int"
#  "QME_sI_ansatz_upart2_sch"
#  "QME_sI_ansatz_upart2_int"
#  "QME_sI_iterative_1"

# %%
n, m = 2, 2
plot(tspan_fs, real(rho_l[1][:, n, m]), label="exact", linealpha = 0.5, linewidth = 3, linestyle = :solid)
plot!(tspan_fs, real(rho_l[2][:, n, m]), label="QME.ansatz.test", linealpha = 0.5, linewidth = 3, linestyle = :solid)
plot!(tspan_fs, real(rho_l[3][:, n, m]), label="QME.ansatz.const_int", linealpha = 0.5, linewidth = 3, linestyle = :dash)
plot!(tspan_fs, real(rho_l[4][:, n, m]), label="QME.ansatz.const_sch", linealpha = 0.5, linewidth = 3, linestyle = :dot)
plot!(tspan_fs, real(rho_l[5][:, n, m]), label="QME.ansatz.upart1_sch", linealpha = 0.5, linewidth = 3, linestyle = :dot)
plot!(tspan_fs, real(rho_l[6][:, n, m]), label="QME.ansatz.upart1_int", linealpha = 0.5, linewidth = 3, linestyle = :dash)
plot!(tspan_fs, real(rho_l[6][:, n, m]), label="QME.ansatz.upart2_sch", linealpha = 0.5, linewidth = 3, linestyle = :dot)
plot!(tspan_fs, real(rho_l[6][:, n, m]), label="QME.ansatz.upart2_int", linealpha = 0.5, linewidth = 3, linestyle = :dash)
plot!(tspan_fs, real(rho_l[6][:, n, m]), label="QME.ansatz.iter1", linealpha = 0.5, linewidth = 3, linestyle = :solid)

p = plot!(ylabel="ρ₂₂(t)", xlabel="t (fs)", margin = 5mm, dpi=400, size=(700,500), ylim=(0, 1))

# %%
n, m = 2, 2
plot(tspan_fs, real(rho_l[1][:, n, m]), label="exact", linealpha = 0.5, linewidth = 3, linestyle = :solid)
plot!(tspan_fs, real(rho_l[2][:, n, m]), label="QME.ansatz.test", linealpha = 0.5, linewidth = 3, linestyle = :solid)
plot!(tspan_fs, real(rho_l[3][:, n, m]), label="QME.ansatz.const_int", linealpha = 0.5, linewidth = 3, linestyle = :dash)
plot!(tspan_fs, real(rho_l[4][:, n, m]), label="QME.ansatz.const_sch", linealpha = 0.5, linewidth = 3, linestyle = :dot)
plot!(tspan_fs, real(rho_l[6][:, n, m]), label="QME.ansatz.iter1", linealpha = 0.5, linewidth = 3, linestyle = :solid)

p = plot!(ylabel="ρ₂₂(t)", xlabel="t (fs)", margin = 5mm, dpi=400, size=(700,500), ylim=(0, 1))

# %%
n, m = 2, 2
plot(tspan_fs, real(rho_l[1][:, n, m]), label="exact", linealpha = 0.5, linewidth = 3, linestyle = :solid)
plot!(tspan_fs, real(rho_l[2][:, n, m]), label="QME.ansatz.test", linealpha = 0.5, linewidth = 3, linestyle = :solid)
plot!(tspan_fs, real(rho_l[3][:, n, m]), label="QME.ansatz.const_int", linealpha = 0.5, linewidth = 3, linestyle = :dash)
plot!(tspan_fs, real(rho_l[6][:, n, m]), label="QME.ansatz.iter1", linealpha = 0.5, linewidth = 3, linestyle = :solid)

p = plot!(ylabel="ρ₂₂(t)", xlabel="t (fs)", margin = 5mm, dpi=400, size=(700,500), ylim=(0, 1))

# %%
n, m = 2, 2
plot(tspan_fs, real(rho_l[1][:, n, m]), label="exact", linealpha = 0.5, linewidth = 3, linestyle = :solid)
plot!(tspan_fs, real(rho_l[2][:, n, m]), label="QME.ansatz.test", linealpha = 0.5, linewidth = 3, linestyle = :solid)
plot!(tspan_fs, real(rho_l[6][:, n, m]), label="QME.ansatz.iter1", linealpha = 0.5, linewidth = 3, linestyle = :solid)

p = plot!(ylabel="ρ₂₂(t)", xlabel="t (fs)", margin = 5mm, dpi=400, size=(700,500))
